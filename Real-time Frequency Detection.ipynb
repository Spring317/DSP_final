# %%
import numpy as np
import pyaudio

NOTE_MIN = 40       # E2
NOTE_MAX = 71       # E4
FSAMP = 22050       # Sampling frequency in Hz
FRAME_SIZE = 2048   # How samples per frame?
FRAMES_PER_FFT = 16 # FFT takes average across how many frames?

SAMPLES_PER_FFT = FRAME_SIZE * FRAMES_PER_FFT
FREQ_STEP = float(FSAMP) / SAMPLES_PER_FFT

def number_to_freq(n):
    return 440 * 2.0 ** ((n - 69) / 12.0)

def note_to_fftbin(n):
    return number_to_freq(n) / FREQ_STEP

imin = max(0, int(np.floor(note_to_fftbin(NOTE_MIN - 1))))
imax = min(SAMPLES_PER_FFT, int(np.ceil(note_to_fftbin(NOTE_MAX + 1))))

buf = np.zeros(SAMPLES_PER_FFT, dtype=np.float32)
num_frames = 0

stream = pyaudio.PyAudio().open(format=pyaudio.paInt16,
                                channels=1,
                                rate=FSAMP,
                                input=True,
                                frames_per_buffer=FRAME_SIZE)

stream.start_stream()

window = 0.5 * (1 - np.cos(np.linspace(0, 2*np.pi, SAMPLES_PER_FFT, False)))

# print ('sampling at', FSAMP, 'Hz with max resolution of', FREQ_STEP, 'Hz')
# print()

while stream.is_active():
    buf[:-FRAME_SIZE] = buf[FRAME_SIZE:]
    buf[-FRAME_SIZE:] = np.fromstring(stream.read(FRAME_SIZE), np.int16)
    
    fft = np.fft.rfft(buf * window)
    
    magnitude = np.abs(fft)
    
    freq = (np.abs(fft[imin:imax]).argmax() + imin) * FREQ_STEP
    
    num_frames += 1
    
    if num_frames >= FRAMES_PER_FFT:
        print(freq)
# Out:
# C:\Users\lViet\AppData\Local\Temp\ipykernel_9528\2154793243.py:40: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   buf[-FRAME_SIZE:] = np.fromstring(stream.read(FRAME_SIZE), np.int16)
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 331.74591064453125
# 331.74591064453125
# 333.7646484375
# 333.7646484375
# 333.09173583984375
# 333.09173583984375
# 333.09173583984375
# 333.09173583984375
# 333.09173583984375
# 333.09173583984375
# 332.4188232421875
# 487.188720703125
# 487.188720703125
# 487.188720703125
# 487.188720703125
# 464.98260498046875
# 186.39678955078125
# 186.39678955078125
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 505.35736083984375
# 213.31329345703125
# 213.31329345703125
# 213.31329345703125
# 213.9862060546875
# 213.31329345703125
# 213.31329345703125
# 470.36590576171875
# 470.36590576171875
# 470.36590576171875
# 468.34716796875
# 468.34716796875
# 469.6929931640625
# 469.02008056640625
# 469.02008056640625
# 469.02008056640625
# 469.02008056640625
# 469.02008056640625
# 306.17523193359375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 474.40338134765625
# 474.40338134765625
# 337.12921142578125
# 334.43756103515625
# 332.4188232421875
# 286.6607666015625
# 286.6607666015625
# 286.6607666015625
# 286.6607666015625
# 333.09173583984375
# 333.09173583984375
# 333.09173583984375
# 333.09173583984375
# 220.71533203125
# 306.84814453125
# 306.84814453125
# 306.84814453125
# 306.84814453125
# 306.84814453125
# 306.84814453125
# 306.84814453125
# 306.84814453125
# 306.17523193359375
# 512.7593994140625
# 505.35736083984375
# 505.35736083984375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 505.35736083984375
# 506.0302734375
# 379.522705078125
# 390.289306640625
# 390.289306640625
# 379.522705078125
# 379.522705078125
# 379.522705078125
# 379.522705078125
# 379.522705078125
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 389.61639404296875
# 389.61639404296875
# 389.61639404296875
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.70318603515625
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
# 506.0302734375
